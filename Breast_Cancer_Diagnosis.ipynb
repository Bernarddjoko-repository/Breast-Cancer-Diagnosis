# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# Define path to your file (adjust if your folder path is different)
file_path = '/content/drive/MyDrive/Breast Cancer/wdbc.data'

# %%
# Define column names based on UCI dataset documentation
columns = ['ID', 'Diagnosis'] + [
    'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean',
    'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
    'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
    'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se', 'fractal_dimension_se',
    'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst',
    'compactness_worst', 'concavity_worst', 'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst'
]

# %%
# Load data
df = pd.read_csv(file_path, header=None, names=columns)

# %%
# Drop the ID column as it’s not useful
df.drop('ID', axis=1, inplace=True)

# %%
# Preview data
df.head()
# Out:
#   Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Check dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave_points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
# Check for missing values
print("\nMissing values in the dataset:")
print(df.isnull().sum())
# Out:
# Missing values in the dataset:
# Diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# Diagnosis label distribution
print("\nDiagnosis distribution:")
print(df['Diagnosis'].value_counts())
# Out:
# Diagnosis distribution:
# Diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Basic summary statistics
print("🔹 Dataset Summary:")
display(df.describe())

# Class distribution (Diagnosis)
print("\n🔹 Diagnosis Class Distribution:")
sns.countplot(x='Diagnosis', data=df, palette='pastel')
plt.title('Diagnosis Class Distribution')
plt.show()

# Encode Diagnosis to 0/1 for modeling later
df['Diagnosis'] = df['Diagnosis'].map({'M': 1, 'B': 0})
# Out:
# 🔹 Dataset Summary:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# ...

# %%
# Plot distribution of a few key features
features_to_plot = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean']
plt.figure(figsize=(16, 8))

for i, col in enumerate(features_to_plot):
    plt.subplot(2, 2, i+1)
    sns.histplot(data=df, x=col, hue='Diagnosis', bins=30, kde=True, palette='coolwarm')
    plt.title(f'Distribution of {col} by Diagnosis')

plt.tight_layout()
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(18, 15))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
### Standardize Numerical Features

# %%
from sklearn.preprocessing import StandardScaler

# Separate features and target
X = df.drop('Diagnosis', axis=1)
y = df['Diagnosis']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert back to DataFrame (for feature names)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

X_scaled_df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Create a new feature: This might capture density or shape variation
X_scaled_df['area_ratio'] = df['area_mean'] / df['perimeter_mean']

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Fit model to get feature importance
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_scaled_df, y)

# Create importance dataframe
importances = pd.DataFrame({
    'feature': X_scaled_df.columns,
    'importance': rf.feature_importances_
}).sort_values(by='importance', ascending=False)

# Display top 10 important features
importances.head(10)
# Out:
#                  feature  importance
# 22       perimeter_worst    0.150944
# 27  concave_points_worst    0.143443
# 23            area_worst    0.108411
# 7    concave_points_mean    0.100931
# 20          radius_worst    0.084783
# 3              area_mean    0.054260
# 13               area_se    0.050582
# 6         concavity_mean    0.050183
# 2         perimeter_mean    0.031702
# 30            area_ratio    0.027553

# %%
# Visualize top features
top_features = importances.head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=top_features, x='importance', y='feature', palette='viridis')
plt.title('Top 10 Feature Importances (Random Forest)')
plt.xlabel('Importance Score')
plt.ylabel('Feature')
plt.show()
# Out:
# <ipython-input-21-f17860f4796c>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_features, x='importance', y='feature', palette='viridis')

# %% [markdown]
# Model Developement

# %%
# Select top 10 features from the importance list
top_10_features = importances.head(10)['feature'].tolist()

# Create reduced feature set
X_top10 = X_scaled_df[top_10_features]

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import pandas as pd

# Step 1: Split with stratification
X_train, X_test, y_train, y_test = train_test_split(
    X_top10, y, test_size=0.2, stratify=y, random_state=42)

# Step 2: Apply SMOTE to training data only
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Check class distribution
print("Original Training Class Distribution:\n", y_train.value_counts())
print("\nResampled Training Class Distribution:\n", pd.Series(y_train_resampled).value_counts())
# Out:
# Original Training Class Distribution:
#  Diagnosis
# 0    285
# 1    170
# Name: count, dtype: int64
#
# Resampled Training Class Distribution:
#  Diagnosis
# 1    285
# 0    285
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert resampled labels to a DataFrame
y_resampled_df = pd.DataFrame(y_train_resampled, columns=['Diagnosis'])
y_resampled_df['Diagnosis'] = y_resampled_df['Diagnosis'].map({0: 'Benign', 1: 'Malignant'})

# Plot
plt.figure(figsize=(5, 4))
sns.countplot(x='Diagnosis', data=y_resampled_df, palette='pastel')
plt.title("Class Distribution After SMOTE")
plt.ylabel("Number of Samples")
plt.xlabel("Diagnosis")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-8582e503b31e>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Diagnosis', data=y_resampled_df, palette='pastel')

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# Define models
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'SVM': SVC(kernel='rbf', probability=True, random_state=42)
}

# Train on resampled training data
for name, model in models.items():
    model.fit(X_train_resampled, y_train_resampled)
    print(f"{name} trained on SMOTE-balanced data.")
# Out:
# Decision Tree trained on SMOTE-balanced data.
# KNN trained on SMOTE-balanced data.
# SVM trained on SMOTE-balanced data.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Evaluate performance
for name, model in models.items():
    y_pred = model.predict(X_test)
    print(f"\n📊 Evaluation for: {name}")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1 Score:", f1_score(y_test, y_pred))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# 📊 Evaluation for: Decision Tree
# Accuracy: 0.9298245614035088
# Precision: 0.8863636363636364
# Recall: 0.9285714285714286
# F1 Score: 0.9069767441860465
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94        72
#            1       0.89      0.93      0.91        42
#
#     accuracy                           0.93       114
#    macro avg       0.92      0.93      0.93       114
# weighted avg       0.93      0.93      0.93       114
#
#
# 📊 Evaluation for: KNN
# Accuracy: 0.9736842105263158
# Precision: 0.975609756097561
# Recall: 0.9523809523809523
# F1 Score: 0.963855421686747
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        72
#            1       0.98      0.95      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Generate predictions
y_pred_dt = models['Decision Tree'].predict(X_test)
y_pred_knn = models['KNN'].predict(X_test)
y_pred_svm = models['SVM'].predict(X_test)

# Set up subplot grid
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Decision Tree
cm_dt = confusion_matrix(y_test, y_pred_dt)
ConfusionMatrixDisplay(cm_dt, display_labels=['Benign', 'Malignant']).plot(ax=axes[0], cmap='Blues')
axes[0].set_title("Decision Tree")

# KNN
cm_knn = confusion_matrix(y_test, y_pred_knn)
ConfusionMatrixDisplay(cm_knn, display_labels=['Benign', 'Malignant']).plot(ax=axes[1], cmap='Greens')
axes[1].set_title("KNN")

# SVM
cm_svm = confusion_matrix(y_test, y_pred_svm)
ConfusionMatrixDisplay(cm_svm, display_labels=['Benign', 'Malignant']).plot(ax=axes[2], cmap='Oranges')
axes[2].set_title("SVM")

# Adjust layout
plt.suptitle("Confusion Matrices for All Models", fontsize=16)
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
import numpy as np

# Use 5-fold stratified cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Store results
cv_results = {}

# Evaluate each model using cross_val_score on the *full* dataset (X_top10)
for name, model in models.items():
    scores = cross_val_score(model, X_top10, y, cv=cv, scoring='accuracy')
    cv_results[name] = scores
    print(f"\n✅ {name} Cross-Validation Results:")
    print("Scores:", scores)
    print("Mean Accuracy:", scores.mean())
    print("Standard Deviation:", scores.std())
# Out:
# ✅ Decision Tree Cross-Validation Results:
# Scores: [0.9122807  0.85964912 0.92105263 0.90350877 0.92920354]
# Mean Accuracy: 0.9051389535786368
# Standard Deviation: 0.024311874553209118
#
# ✅ KNN Cross-Validation Results:
# Scores: [0.97368421 0.92105263 0.92982456 0.93859649 0.95575221]
# Mean Accuracy: 0.9437820214252446
# Standard Deviation: 0.018845434254605158
#
# ✅ SVM Cross-Validation Results:
# Scores: [0.97368421 0.9122807  0.93859649 0.92982456 0.95575221]
# Mean Accuracy: 0.9420276354603322
# Standard Deviation: 0.02114743761723622

# %%
import matplotlib.pyplot as plt

# Prepare data
models_list = list(cv_results.keys())
means = [cv_results[m].mean() for m in models_list]
stds = [cv_results[m].std() for m in models_list]

# Plot
plt.figure(figsize=(8, 5))
plt.bar(models_list, means, yerr=stds, capsize=5, color=['skyblue', 'lightgreen', 'salmon'])
plt.ylabel('Mean Accuracy')
plt.title('Cross-Validation Accuracy with Error Bars (±1 std)')
plt.ylim(0.85, 1.0)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# **Model Performance Comparison Plot**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame for model performance metrics (from test set)
model_scores = {
    'Model': ['Decision Tree', 'KNN', 'SVM'],
    'Accuracy': [0.9298, 0.9737, 0.9649],
    'Precision': [0.8864, 0.9756, 0.9524],
    'Recall': [0.9286, 0.9524, 0.9524],
    'F1 Score': [0.9070, 0.9639, 0.9524]
}

scores_df = pd.DataFrame(model_scores)

# Melt for seaborn-style grouped bar plot
scores_melted = scores_df.melt(id_vars='Model', var_name='Metric', value_name='Score')

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Metric', y='Score', hue='Model', data=scores_melted, palette='Set2')
plt.title('📊 Model Performance Comparison')
plt.ylim(0.8, 1.0)
plt.legend(title='Model')
plt.grid(axis='y')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **Decision Boundary Visualizations**

# %%
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
import numpy as np

# Reduce to 2D using PCA for plotting
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_top10)

# Create a dictionary of models already trained
trained_models = {
    'Decision Tree': models['Decision Tree'],
    'KNN': models['KNN'],
    'SVM': models['SVM']
}

# Retrain on PCA-reduced data
for name in trained_models:
    trained_models[name].fit(X_pca, y)

# Set up mesh grid for decision surface
x_min, x_max = X_pca[:, 0].min() - 1, X_pca[:, 0].max() + 1
y_min, y_max = X_pca[:, 1].min() - 1, X_pca[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.05),
                     np.arange(y_min, y_max, 0.05))

# Plot decision boundaries
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA'])
cmap_bold = ['#FF0000', '#00FF00']

for idx, (name, model) in enumerate(trained_models.items()):
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    axes[idx].contourf(xx, yy, Z, cmap=cmap_light, alpha=0.6)
    axes[idx].scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap=ListedColormap(cmap_bold), edgecolor='k', s=20)
    axes[idx].set_title(f"{name} Decision Boundary (PCA 2D)")
    axes[idx].set_xlabel("PCA Component 1")
    axes[idx].set_ylabel("PCA Component 2")

plt.tight_layout()
plt.show()
